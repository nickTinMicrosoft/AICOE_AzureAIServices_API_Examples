# %% [markdown]
# ##
#
# * setx LANGUAGE_KEY your-key
# * setx LANGUAGE_ENDPOINT your-endpoint

# %%
# pip install azure-ai-textanalytics==5.2.0

# %%
from azure.ai.textanalytics import TextAnalyticsClient
from azure.core.credentials import AzureKeyCredential
import os

# %%
# This example requires environment variables named "LANGUAGE_KEY" and "LANGUAGE_ENDPOINT"
language_key = os.environ.get('LANGUAGE_KEY')
language_endpoint = os.environ.get('LANGUAGE_ENDPOINT')
# Out:
# https://eastus.api.cognitive.microsoft.com/:b755ad4648ee4495b6c245938febb850

# %%
# Authenticate the client using your key and endpoint 
def authenticate_client():
    ta_credential = AzureKeyCredential(language_key)
    text_analytics_client = TextAnalyticsClient(
            endpoint=language_endpoint, 
            credential=ta_credential)
    return text_analytics_client

client = authenticate_client()

# Example method for detecting sentiment and opinions in text 
def sentiment_analysis_with_opinion_mining_example(client, documents=["The food and service were unacceptable. The concierge was nice, however."]):

    result = client.analyze_sentiment(documents, show_opinion_mining=True)
    doc_result = [doc for doc in result if not doc.is_error]

    positive_reviews = [doc for doc in doc_result if doc.sentiment == "positive"]
    negative_reviews = [doc for doc in doc_result if doc.sentiment == "negative"]

    positive_mined_opinions = []
    mixed_mined_opinions = []
    negative_mined_opinions = []

    for document in doc_result:
        print("Document Sentiment: {}".format(document.sentiment))
        print("Overall scores: positive={0:.2f}; neutral={1:.2f}; negative={2:.2f} \n".format(
            document.confidence_scores.positive,
            document.confidence_scores.neutral,
            document.confidence_scores.negative,
        ))
        for sentence in document.sentences:
            print("Sentence: {}".format(sentence.text))
            print("Sentence sentiment: {}".format(sentence.sentiment))
            print("Sentence score:\nPositive={0:.2f}\nNeutral={1:.2f}\nNegative={2:.2f}\n".format(
                sentence.confidence_scores.positive,
                sentence.confidence_scores.neutral,
                sentence.confidence_scores.negative,
            ))
            for mined_opinion in sentence.mined_opinions:
                target = mined_opinion.target
                print("......'{}' target '{}'".format(target.sentiment, target.text))
                print("......Target score:\n......Positive={0:.2f}\n......Negative={1:.2f}\n".format(
                    target.confidence_scores.positive,
                    target.confidence_scores.negative,
                ))
                for assessment in mined_opinion.assessments:
                    print("......'{}' assessment '{}'".format(assessment.sentiment, assessment.text))
                    print("......Assessment score:\n......Positive={0:.2f}\n......Negative={1:.2f}\n".format(
                        assessment.confidence_scores.positive,
                        assessment.confidence_scores.negative,
                    ))
            print("\n")
        print("\n")
          
sentiment_analysis_with_opinion_mining_example(client)
# Out:
# Document Sentiment: mixed
# Overall scores: positive=0.30; neutral=0.17; negative=0.52
#
# Sentence: The food and service were unacceptable.
# Sentence sentiment: negative
# Sentence score:
# Positive=0.00
# Neutral=0.00
# Negative=1.00
#
# ......'negative' target 'food'
# ......Target score:
# ......Positive=0.01
# ......Negative=0.99
#
# ......'negative' assessment 'unacceptable'
# ......Assessment score:
# ......Positive=0.01
# ......Negative=0.99
#
# ......'negative' target 'service'
# ......Target score:
# ......Positive=0.01
# ......Negative=0.99
#
# ......'negative' assessment 'unacceptable'
# ......Assessment score:
# ......Positive=0.01
# ......Negative=0.99
#
#
#
# Sentence: The concierge was nice, however.
# Sentence sentiment: positive
# Sentence score:
# Positive=0.61
# Neutral=0.35
# Negative=0.05
#
# ......'positive' target 'concierge'
# ......Target score:
# ......Positive=1.00
# ......Negative=0.00
#
# ......'positive' assessment 'nice'
# ......Assessment score:
# ......Positive=1.00
# ......Negative=0.00

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests


url = 'https://www.dot.nd.gov/contact-us'

# html = urllib.request.urlopen(url).read()

headers = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.182 Safari/537.36"}
webpage = requests.get(url,headers=headers)

soup = BeautifulSoup(webpage.content, 'html.parser')
# print(soup)


text = soup.find_all('p')
# text = text[0].text
# print(text)

mytext = text[3].text

textList = []

for t in text:
    textList.append(t.text)

# %%
print(textList)
# Out:
# ['An official website of the State of North Dakota', 'Language: English', 'The State of North Dakota provides automatic translation for nd.gov websites, courtesy of Google Translate. Please remember, though, that the English language version is considered the most accurate. In the event of a disagreement or discrepancy between the translation and the original English version of this web site or any notice or disclaimer, the original version will prevail.', '608 East Boulevard AvenueBismarck, ND 58505-0700Ph: 701-328-2500Ph: 1-855-NDROADS (637-6237)TTY Number: 711 or 1-800-366-6888', 'Free travel information service is available 24 hours a day by visiting the travel map or downloading the ND Roads app.\xa0', 'View the NDDOT Districts webpage for more information.\xa0', 'Copyright\xa0 | North Dakota Department of Transportation\xa0608 East Boulevard Avenue | Bismarck, ND 58505-0700 | 701-328-2500']

# %%
sentiment_analysis_with_opinion_mining_example(client, textList)
# Out:
# Document Sentiment: neutral
# Overall scores: positive=0.00; neutral=1.00; negative=0.00
#
# Sentence: An official website of the State of North Dakota
# Sentence sentiment: neutral
# Sentence score:
# Positive=0.00
# Neutral=1.00
# Negative=0.00
#
#
#
#
#
# Document Sentiment: neutral
# Overall scores: positive=0.00; neutral=1.00; negative=0.00
#
# Sentence: Language: English
# Sentence sentiment: neutral
# Sentence score:
# Positive=0.00
# Neutral=1.00
# Negative=0.00
#
#
#
#
#
# Document Sentiment: negative
# Overall scores: positive=0.01; neutral=0.29; negative=0.70
#
# Sentence: The State of North Dakota provides automatic translation for nd.gov websites, courtesy of Google Translate.
# Sentence sentiment: neutral
# Sentence score:
# Positive=0.00
# Neutral=1.00
# Negative=0.00
#
#
#
# Sentence: Please remember, though, that the English language version is considered the most accurate.
# Sentence sentiment: neutral
# Sentence score:
# Positive=0.03
# Neutral=0.95
# Negative=0.02
#
#
#
# Sentence: In the event of a disagreement or discrepancy between the translation and the original English version of this web site or any notice or disclaimer, the original version will prevail.
# Sentence sentiment: negative
# Sentence score:
# Positive=0.01
# Neutral=0.29
# Negative=0.70
#
#
#
#
#
# Document Sentiment: neutral
# Overall scores: positive=0.00; neutral=1.00; negative=0.00
#
# Sentence: 608 East Boulevard AvenueBismarck, ND 58505-0700Ph: 701-328-2500Ph: 1-855-NDROADS (637-6237)TTY Number: 711 or 1-800-366-6888
# Sentence sentiment: neutral
# Sentence score:
# Positive=0.00
# Neutral=1.00
# Negative=0.00
#
#
#
#
#
# Document Sentiment: neutral
# Overall scores: positive=0.01; neutral=0.99; negative=0.00
#
# Sentence: Free travel information service is available 24 hours a day by visiting the travel map or downloading the ND Roads app.
# Sentence sentiment: neutral
# Sentence score:
# Positive=0.01
# Neutral=0.99
# Negative=0.00
#
# ......'positive' target 'travel information service'
# ......Target score:
# ......Positive=1.00
# ......Negative=0.00
#
# ......'positive' assessment 'Free'
# ......Assessment score:
# ......Positive=1.00
# ......Negative=0.00
#
#
#
#
#
# Document Sentiment: neutral
# Overall scores: positive=0.00; neutral=1.00; negative=0.00
#
# Sentence: View the NDDOT Districts webpage for more information.
# Sentence sentiment: neutral
# Sentence score:
# Positive=0.00
# Neutral=1.00
# Negative=0.00
#
#
#
#
#
# Document Sentiment: neutral
# Overall scores: positive=0.01; neutral=0.99; negative=0.00
#
# Sentence: Copyright  |
# Sentence sentiment: neutral
# Sentence score:
# Positive=0.03
# Neutral=0.96
# Negative=0.01
#
#
#
# Sentence: North Dakota Department of Transportation 608 East Boulevard Avenue |
# Sentence sentiment: neutral
# Sentence score:
# Positive=0.00
# Neutral=1.00
# Negative=0.00
#
#
#
# Sentence: Bismarck, ND 58505-0700 |
# Sentence sentiment: neutral
# Sentence score:
# Positive=0.00
# Neutral=1.00
# Negative=0.00
#
#
#
# Sentence: 701-328-2500
# Sentence sentiment: neutral
# Sentence score:
# Positive=0.00
# Neutral=1.00
# Negative=0.00
